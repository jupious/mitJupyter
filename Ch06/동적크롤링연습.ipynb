# %%
from selenium import webdriver
from bs4 import BeautifulSoup

wd = webdriver.Chrome()
wd.get('https://naver.com')

# logelement = wd.find_element_by_class_name("MyView-module__link_login___HpHMW")
# logelement.click()
#inputtest = wd.find_element_by_id("id")
#inputtest.send_keys("jupious")
# passwd = wd.find_element_by_id("pw")
# passwd.send_keys("rhkrehdrb354")
# login = wd.find_element_by_id("log.login")
# login.click()
# wd.back()
# wd.forward()
# wd.refresh()
# wd.back()

searchelem = wd.find_element_by_id("query")
searchelem.send_keys("aaa\n")
# searchbtn = wd.find_element_by_id("search-btn")
# searchbtn.click()
html_str = wd.page_source
bs = BeautifulSoup(html_str,'html.parser')
# Out:
# <html data-platform="win32" data-useragent="mozilla/5.0 (windows nt 10.0; win64; x64) applewebkit/537.36 (khtml, like gecko) chrome/119.0.0.0 safari/537.36" lang="ko"><head> <meta charset="utf-8"/> <meta content="always" name="referrer"/> <meta content="telephone=no,address=no,email=no" name="format-detection"/> <meta content="aaa : 네이버 통합검색" property="og:title"/> <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/> <meta content="'aaa'의 네이버 통합검색 결과입니다." property="og:description"/> <meta content="'aaa'의 네이버 통합검색 결과입니다." lang="ko" name="description"/> <title>aaa : 네이버 통합검색</title> <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico" rel="shortcut icon"/> <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml"/><link href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_231109.css" rel="stylesheet" type="text/cs
# ...

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time

wd = webdriver.Chrome()
wd.get('https://www.coffeebeankorea.com/store/store.asp')
wd.execute_script('storePop2("31")')
html = wd.page_source
bs = BeautifulSoup(html,'html.parser')
store_info = bs.find('div',attrs={'class':'popup_inner'})
print(store_info)
#print(store_info.find('h2'), store_info.find('td'))
# Out:
# None
