# %%
import urllib.request
from bs4 import BeautifulSoup #html 구문분석라이브러리

response = urllib.request.urlopen("https://www.naver.com")
html_str = response.read().decode("utf-8")
bs = BeautifulSoup(html_str,'html.parser')
#print(bs.prettify())
#bs.a #첫번째 a태그
#bs.find_all('a') #모든 a태그 찾기
#bs.select_one("#u_skip > a:nth-child(1) > span") #selector에 해당하는 첫번째 요소
#selected = bs.select("#feed > div.feed_area > div.feed_box > ul.SixColumnPoster-module__common_list___OAMMz > li.SixColumnPoster-module__common_item___kpJBO") #selector에 해당하는 모든요소
#bs.find("a",attrs={'href':"#topAsideButton"})
# Out:
# <a href="#topAsideButton"><span>상단영역 바로가기</span></a>

# %%
response = urllib.request.urlopen("https://search.naver.com/search.naver?where=nexearch&sm=tab_etc&qvt=0&query=%EB%B0%95%EC%8A%A4%EC%98%A4%ED%94%BC%EC%8A%A4")
html_str = response.read().decode("utf-8")
bs = BeautifulSoup(html_str,'html.parser')
#bs.find('ul',attrs={'class':'_panel'})
selected = bs.find('div',attrs={'class':'list_image_box'}).find_all('div', attrs={'class':'title_box'})
for line in selected:
    print(line.find('strong').string,"(",line.find('span').string,")")
# Out:
# 더 마블스 ( 5만명 )
# 그대들은 어떻게 살 것인가 ( 1.9만명 )
# 소년들 ( 1.3만명 )
# 뉴 노멀 ( 8,853명 )
# 30일 ( 6,807명 )
# 서울의 봄 ( 5,736명 )
# 톡 투 미 ( 4,753명 )
# 극장판 아이돌리쉬 세븐; 라... ( 2,743명 )
# 극장판 아이돌리쉬 세븐; 라... ( 2,587명 )
# 1947 보스톤 ( 2,210명 )
# 용감한 시민 ( 1,687명 )
# 만추 리마스터링 ( 1,577명 )
# 괴인 ( 1,225명 )
# 블루 자이언트 ( 1,135명 )
# 테일러 스위프트 디 에라스 ... ( 928명 )
# 플라워 킬링 문 ( 791명 )
# 다이브: 100피트 추락 ( 748명 )
# 녹야 ( 624명 )
# 시뮬런트 ( 529명 )
# 어른 김장하 ( 487명 )
# 너와 나 ( 409명 )
# 만분의 일초 ( 400명 )
# 원 모어 찬스 ( 396명 )
# 바람 따라 만나리 : 김호중... ( 367명 )
# 마이 샤이니 월드 ( 358명 )
# 수라 ( 297명 )
# 드림쏭2 ( 270명 )
# 5시부터 7시까지의 주희 ( 266명 )
# 빌리와 용감한 녀석들: 황금... ( 259명 )
# 약속 ( 256명 )

# %%
response = urllib.request.urlopen("https://search.naver.com/search.naver?where=nexearch&sm=top_hty&fbm=0&ie=utf8&query=%EC%9B%B9%ED%88%B0+%EC%A3%BC%EA%B0%84+%EB%9E%AD%ED%82%B9")
html_str = response.read().decode("utf-8")
bs = BeautifulSoup(html_str,'html.parser')
selected = bs.find_all('div', attrs={'class':'title_box'})
for index,line in enumerate(selected):
    if(index < 10):
        print(str(index+1)+"등",line.strong.string,"-",line.span.string)
    else:
        break
# Out:
# 1등 화산귀환 -  LICO
# 2등 외모지상주의 -  박태준
# 3등 김부장 -  박태준 만화회사/정종택
# 4등 신혼일기 -  자까
# 5등 퀘스트지상주의 -  박태준 만화회사, 유누니/박태준 만화회사, 태완
# 6등 전지적 독자 시점 -  UMI/슬리피-C
# 7등 싸움독학 -  박태준 만화회사/김정현 스튜디오
# 8등 촉법소년 -  박태준 만화회사, 남자의 이야기/정종택
# 9등 프리드로우 -  전선욱
# 10등 나 혼자 만렙 뉴비 -  WAN.Z/스윙뱃

# %%
import urllib.request
from bs4 import BeautifulSoup #html 구문분석라이브러리
request = urllib.request.Request("https://www.coupang.com/np/search?rocketAll=false&searchId=a93773ac33424777a23c952663fb7721&q=%EB%85%B8%ED%8A%B8%EB%B6%81&brand=&offerCondition=&filter=&availableDeliveryFilter=&filterType=&isPriceRange=false&priceRange=&minPrice=&maxPrice=&page=1&trcid=&traid=&filterSetByUser=true&channel=user&backgroundColor=&searchProductCount=1142950&component=&rating=0&sorter=salePriceAsc&listSize=36")
request.add_header("user-agent",'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36')
request.add_header("accept-language","ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7")
response = urllib.request.urlopen(request)
html_str = response.read().decode("utf-8")
BeautifulSoup(html_str,'html.parser')
# Out:
# <!DOCTYPE html>
#
# <!--[if lte IE 7 ]><html class="lt-ie9 lt-ie8" lang="ko-KR"><![endif]-->
# <!--[if IE 8 ]><html class="lt-ie9" lang="ko-KR"><![endif]-->
# <!--[if (gte IE 9)|!(IE)]><!--><html lang="ko-KR"><!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="zaNrGtrOLMjglkziY2IvmL8dOXyCWHGArDHqFazJQVI" name="google-site-verification"/>
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="//cart.coupang.com" rel="dns-prefetch"/>
# <link href="//assets.coupang.com" rel="dns-prefetch"/>
# <link href="//assets2.coupang.com" rel="dns-prefetch"/>
# <link href="//assets.coupangcdn.com" rel="dns-prefetch"/>
# <link href="//asset1.coupangcdn.com" rel="dns-prefetch"/>
# <link href="//private.coupang.com" rel="dns-prefetch"/>
# <link href="//img1a.coupangcdn.com" rel="dns-prefetch"/>
# <link href="//image1.coupangcdn.com" rel="dns-prefetch"/>
# <link href="//thumbnail1.coupangcdn.com" rel="dns-prefetch"/>
# ...

# %%
import requests
from bs4 import BeautifulSoup #html 구문분석라이브러리
newheader = {"user-agent":'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36',
             "accept-language":"ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7"}
find_list = []
index = 0
for page in range(1,4):
    url="https://www.coupang.com/np/search?rocketAll=false&searchId=a93773ac33424777a23c952663fb7721&q=%EB%85%B8%ED%8A%B8%EB%B6%81&brand=&offerCondition=&filter=&availableDeliveryFilter=&filterType=&isPriceRange=false&priceRange=&minPrice=&maxPrice=&page="+str(page)+"&trcid=&traid=&filterSetByUser=true&channel=user&backgroundColor=&searchProductCount=1142950&component=&rating=0&sorter=salePriceAsc&listSize=36"
    html_str = requests.get(url,headers=newheader).text
    bs = BeautifulSoup(html_str,"html.parser")
    find_list.append(bs.find_all('dl',attrs={'class':'search-product-wrap'}))
for p in find_list:
    for line in p:
        if index < 100:
            print(index+1,"등",line.find('div',attrs={'class':'name'}).string,"가격:",line.strong.string+"원")
        else:
            break
        index += 1
# Out:
# 1 등 A급중고/삼성/LG/HP I5 I7 리퍼 중고노트북 리퍼노트북 게이밍노트북 기본SSD장착 WIN10, HP 430-G2, WIN10 Pro, 8GB, 128GB, 코어i5, 블랙 가격: 149,000원
# 2 등 삼성 노트북/NT200B5C/NT371B5J /I5 3320M 4G SSD128G/15.6인치 WIN10 Pro 가격: 159,000원
# 3 등 삼성전자 삼성노트북 NT200B5C/i5-3210/4G/SSD128G/DVD멀티/15.6/1600*900/윈도우10/2.3kg/무상보증1년, NT200B5C, WIN10 Pro, 4GB, 128GB, 코어i5, 블랙 가격: 159,000원
# 4 등 특가할인 레노버 씽크패드 X240 4세대 i5 인텔HD 12.5인치 윈도우10, WIN10, 4GB, 128GB, 코어i5, 블랙 가격: 175,000원
# 5 등 이태원클라쓰북 그램스타일 노트북 넥스트북 풀패키지미개봉 NB141LTN41 8세대 14 IPS FHD 윈11 프로 탑재, NB144LTN41, WIN11 Pro, 4GB, 64GB, 셀러론, 화이트 가격: 199,000원
# 6 등 디클 클릭북 D141+ 노트북, 화이트, 디클 클릭북 D141+ 플러스 IPS, 아톰, 64GB, 4GB, WIN10 Pro 가격: 242,690원
# 7 등 아이뮤즈 스톰북 노트북 N4020 35.81cm, White, 셀러론, 64GB, 4GB, WIN10 Home, StormBooK14 가격: 246,510원
# 8 등 A급중고 LG 15N540 I5-4310M/16G/SSD256G/HD4600/15.6 HD/WIN10 게이밍북, WIN10 Pro, 16GB, 256GB, 코어i5, 실버 가격: 249,000원
# 9 등 삼성 사무용 인강 노트북 인텔 i5 i7 SSD장착 윈10 홈, NT370E, WIN10 Home, 8GB, 128GB, 코어i5 4세대, 블랙 가격: 259,000원
# ...

# %%
import requests
from bs4 import BeautifulSoup #html 구문분석라이브러리
locate = ('서울','경기','인천','강원','경남','광주','대전','대구','부산','제주','충남','충북')
#result = {}
result2 = []
for local in locate:
    url = 'https://www.coffeebeankorea.com/store/store_data2.asp?lat=&lng=&chk1=0&chk2=0&chk3=0&chk4=0&chk5=0&chk6=0&chk7=0&chk8=0&chk9=0&chk10=0&chk11=0&chk12=0&chk13=0&keyword=&StoreLocal='+local+'&StoreLocal2=&storeNo='
    html_str = requests.get(url).text
    bs = BeautifulSoup(html_str,"html.parser")
    name_index = []

    for data in bs:
        sp = str(data).split("'")
        isName = False
        isTime = False
        name = ""
        time = ""
        for i in sp:
            if isName:
                name = i
                isName=False
            if isTime:
                time = i
                isTime=False
            if i == ", StoreName : ":
                isName = True
            if i == " , StoreOpendate : ":
                isTime = True
            if name != "" and time != "":
                #result[name] = time
                result2.append(name)
                result2.append(time)
                name = ""
                time = ""
    
# for name, time in result.items():
#     print("{} : {}".format(name,time))
#혹시나 매장명 겹칠까봐 리스트로 바꿈
print("총 매장 수",len(result2)//2)
for i in range(0,len(result2),2):
    print(result2[i],":",result2[i+1])
# Out:
# 총 매장 수 138
# 고대안암병원신관점 :  l 월~금 07:00~22:00 l 주말,공휴일 09:00~20:00 l
# 압구정로데오2호점 : 월-목 08:00~23:00 | 금-토 08:00~24:00 | 일/공휴일 08:00~22:00
# 종로YBM별관점 : | 월~금 07:30~22:00 l 주말,공휴일 08:00~22:00 l
# 서울시청점 : 월-일 07:00 ~ 22:00
# 성균관대법학관점 : 월~금 08:00 ~ 20:00 | 토 09:00 ~ 17:00 | 일 휴점
# 하나금융명동사옥점 : 월~금 06:30 ~ 22:00 | 토,일 08:00 ~ 22:00
# 용산아이파크몰점 : 매일 08:00 ~ 22:00
# 상암SBS프리즘타워점 : 월~금 07:00 ~ 19:00 | 토 09:00 ~ 17:00 | 일 휴무
# 명동거리점 : 매일 07:00 ~ 00:00
# 혜화역점 : 매일 08:00 ~ 00:00
# 서초중앙로점 : 평일 07:00~22:00 | 토-일 07:30~22:00
# 청계천을지로점 : 평일 06:30 ~ 23:00 | 주말 09:00~22:00
# 송파헬리오시티점 : 평일 07:00~21:30 | 주말 07:00~22:00
# 수서역원방빌딩점 : 평일 06:30 ~ 21:30 | 주말 07:00 ~ 21:30
# KB국민은행노원역점 : 평일 07:00~21:00 | 토 08:00~21:00 | 일 휴무
# 이태원몬드리안호텔점 : 평일 08:00~22:30 | 주말/공휴일 08:00~22:30
# 논현역8번출구점 : 월-금 07:00~22:00 | 토 08:00~22:00 | 일/공휴일 08:00~22:00 |
# 선릉KSA한국표준협회점 : 월-금 07:00~21:00 | 토요일 07:00~21:00 | 일요일 08:00~21:00
# 하나은행을지로본점 : | 월-금 07:00~19:00 | 주말/공휴일 휴무
# 삼성루첸타워점 : 월-금 07:00~20:00 | 주말,공휴일 10:00~18:00
# ...

# %%
import requests
locate = ('서울','경기','인천','강원','경남','광주','대전','대구','부산','제주','충남','충북')
#result = {}
result2 = []
test = []
for local in locate:
    url = 'https://www.coffeebeankorea.com/store/store_data2.asp?lat=&lng=&chk1=0&chk2=0&chk3=0&chk4=0&chk5=0&chk6=0&chk7=0&chk8=0&chk9=0&chk10=0&chk11=0&chk12=0&chk13=0&keyword=&StoreLocal='+local+'&StoreLocal2=&storeNo='
    html_str = requests.get(url).text

    sp = html_str.split("'")
    isName = False
    isTime = False
    name = ""
    time = ""
    for i in sp:
        if isName:
            name = i
            isName=False
        if isTime:
            time = i
            isTime=False
        if i == ", StoreName : ":
            isName = True
        if i == " , StoreOpendate : ":
            isTime = True
        if name != "" and time != "":
            #result[name] = time
            result2.append(name)
            result2.append(time)
            name = ""
            time = ""
    
# for name, time in result.items():
#     print("{} : {}".format(name,time))
#혹시나 매장명 겹칠까봐 리스트로 바꿈
print("총 매장 수",len(result2)//2)
for i in range(0,len(result2),2):
    print(result2[i],":",result2[i+1])
# Out:
# 총 매장 수 138
# 고대안암병원신관점 :  l 월~금 07:00~22:00 l 주말,공휴일 09:00~20:00 l
# 압구정로데오2호점 : 월-목 08:00~23:00 | 금-토 08:00~24:00 | 일/공휴일 08:00~22:00
# 종로YBM별관점 : | 월~금 07:30~22:00 l 주말,공휴일 08:00~22:00 l
# 서울시청점 : 월-일 07:00 ~ 22:00
# 성균관대법학관점 : 월~금 08:00 ~ 20:00 | 토 09:00 ~ 17:00 | 일 휴점
# 하나금융명동사옥점 : 월~금 06:30 ~ 22:00 | 토,일 08:00 ~ 22:00
# 용산아이파크몰점 : 매일 08:00 ~ 22:00
# 상암SBS프리즘타워점 : 월~금 07:00 ~ 19:00 | 토 09:00 ~ 17:00 | 일 휴무
# 명동거리점 : 매일 07:00 ~ 00:00
# 혜화역점 : 매일 08:00 ~ 00:00
# 서초중앙로점 : 평일 07:00~22:00 | 토-일 07:30~22:00
# 청계천을지로점 : 평일 06:30 ~ 23:00 | 주말 09:00~22:00
# 송파헬리오시티점 : 평일 07:00~21:30 | 주말 07:00~22:00
# 수서역원방빌딩점 : 평일 06:30 ~ 21:30 | 주말 07:00 ~ 21:30
# KB국민은행노원역점 : 평일 07:00~21:00 | 토 08:00~21:00 | 일 휴무
# 이태원몬드리안호텔점 : 평일 08:00~22:30 | 주말/공휴일 08:00~22:30
# 논현역8번출구점 : 월-금 07:00~22:00 | 토 08:00~22:00 | 일/공휴일 08:00~22:00 |
# 선릉KSA한국표준협회점 : 월-금 07:00~21:00 | 토요일 07:00~21:00 | 일요일 08:00~21:00
# 하나은행을지로본점 : | 월-금 07:00~19:00 | 주말/공휴일 휴무
# 삼성루첸타워점 : 월-금 07:00~20:00 | 주말,공휴일 10:00~18:00
# ...
